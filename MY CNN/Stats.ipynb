# %% [markdown]
# ### DATA:
#     Class count:    3(Ellipse, triangle, quadrilateral)
#     Coluours:       Grayscale
#     Shape Type:     Perimeter only
#     Blur:           No
#     Line Thickness: Constant
#     Image Count:    10000 per class(30000 total)
#     Size:           40 x 40
#
# ### TRAINING:
#     Train on 24000 samples,
#     validate on 4800 samples
#     50 epochs
#     batch size 128
#     kernel size (6,6)
#     alpha 0.001
#
# ### RESULTS:
#     Training dataset:          loss = 0.1042, accuracy = 0.9682
#     Cross-validation dataset:  loss = 0.1798, accuracy = 0.9383
#     Test dataset:              loss = 0.1933, accuracy = 0.9408
#     Time:                      2min 32s
#
#
#     Training dataset:          loss = 0.0750, accuracy = 0.9737
#     Cross-validation dataset:  loss = 0.1738, accuracy = 0.9417
#     Test dataset:              loss = 0.1662, accuracy = 0.9450
#     Time:                      2min 29s

# %% [markdown]
# ### DATA:
#     Class count:               3(Ellipse, triangle, quadrilateral)
#     Coluours:                  Grayscale
#     Shape Type:                Perimeter only
#     Blur:                      No
#     Line Thickness:            Constant
#     Image Count:               10000 per class(30000 total)
#     Size:                      40 x 40
#
# ### TRAINING:
#     Train on:                  24000 samples,
#     Validate on:               4800 samples
#     Epochs:                    50
#     Batch size:                128
#     Kernel size:               6 x 6
#    - Learning Rate:             0.01
#
# ### RESULTS:
#     Training dataset:          loss = 1.0988, accuracy = 0.3318
#     Cross-validation dataset:  loss = 1.0986, accuracy = 0.3352
#     Test dataset:              loss = 1.0980, accuracy = 0.3558
#     Time:                      2min 29s

# %% [markdown]
# ### DATA:
#     Class count:               3(Ellipse, triangle, quadrilateral)
#     Coluours:                  Grayscale
#     Shape Type:                Perimeter only
#     Blur:                      No
#     Line Thickness:            Constant
#     Image Count:               10000 per class(30000 total)
#     Size:                      40 x 40
#
# ### TRAINING:
#     Train on:                  24000 samples,
#     Validate on:               4800 samples
#     Epochs:                    50
#     Batch size:                128
#     Kernel size:               6 x 6
#    - Learning Rate:             0.0001
#
# ### RESULTS:
#     Training dataset:          loss = 0.3357, accuracy = 0.8481
#     Cross-validation dataset:  loss = 0.3599, accuracy = 0.8358
#     Test dataset:              loss = 0.3599, accuracy = 0.8458
#     Time:                      2min 27s
#
#     Training dataset:          loss = 0.3390, accuracy = 0.8507
#     Cross-validation dataset:  loss = 0.3648, accuracy = 0.8338
#     Test dataset:              loss = 0.3635, accuracy = 0.8383
#     Time:                      2min 26s

# %% [markdown]
# ### DATA:
#     Class count:               3(Ellipse, triangle, quadrilateral)
#     Coluours:                  Grayscale
#     Shape Type:                Perimeter only
#     Blur:                      No
#     Line Thickness:            Constant
#     Image Count:               10000 per class(30000 total)
#     Size:                      40 x 40
#
# ### TRAINING:
#     Train on:                  24000 samples,
#     Validate on:               4800 samples
#     Epochs:                    50
#     Batch size:                128
#     Kernel size:               6 x 6
#    - Learning Rate:             0.003
#
# ### RESULTS:
#     Training dataset:          loss = 0.0860, accuracy = 0.9705
#     Cross-validation dataset:  loss = 0.1979, accuracy = 0.9346
#     Test dataset:              loss = 0.1866, accuracy = 0.9425
#     Time:                      2min 27s
#
#     Training dataset:          loss = 0.1371, accuracy = 0.9481
#     Cross-validation dataset:  loss = 0.2183, accuracy = 0.9169
#     Test dataset:              loss = 0.2263, accuracy = 0.9050
#     Time:                      2min 29s
#
#     Training dataset:          loss = 0.0903, accuracy = 0.9699
#     Cross-validation dataset:  loss = 0.2002, accuracy = 0.9360
#     Test dataset:              loss = 0.1736, accuracy = 0.9325
#     Time:                      2min 23s
#
#     Training dataset:          loss = 0.1423, accuracy = 0.9473
#     Cross-validation dataset:  loss = 0.2241, accuracy = 0.9206
#     Test dataset:              loss = 0.2288, accuracy = 0.9175
#     Time:                      2min 23s

# %% [markdown]
# ### DATA:
#     Class count:               3(Ellipse, triangle, quadrilateral)
#     Coluours:                  Grayscale
#     Shape Type:                Perimeter only
#     Blur:                      No
#     Line Thickness:            Constant
#     Image Count:               10000 per class(30000 total)
#     Size:                      40 x 40
#
# ### TRAINING:
#     Train on:                  24000 samples,
#     Validate on:               4800 samples
#     Epochs:                    50
#     Batch size:                128
#     Kernel size:               6 x 6
#    - Learning Rate:             0.0003
#
# ### RESULTS:
#     Training dataset:          loss = 0.1703, accuracy = 0.9406
#     Cross-validation dataset:  loss = 0.2240, accuracy = 0.9115
#     Test dataset:              loss = 0.2254, accuracy = 0.8992
#     Time:                      2min 24s
#
#     Training dataset:          loss = 0.1731, accuracy = 0.9390
#     Cross-validation dataset:  loss = 0.2287, accuracy = 0.9069
#     Test dataset:              0.2294, accuracy = 0.9008
#     Time:                      2min 28s

# %% [markdown]
# ### DATA:
#     Class count:    3(Ellipse, triangle, quadrilateral)
#     Coluours:       Grayscale
#     Shape Type:     Perimeter only
#     Blur:           No
#     Line Thickness: Constant
#     Image Count:    10000 per class(30000 total)
#     Size:           40 x 40
#
# ### TRAINING:
#     Train on 24000 samples,
#     validate on 4800 samples
#     50 epochs
#     batch size 128
#    - kernel size (3,3)
#
#     alpha 0.001
#
# ### RESULTS:
#     Training dataset:          loss = 0.1985, accuracy = 0.9239
#     Cross-validation dataset:  loss = 0.2872, accuracy = 0.8694
#     Test dataset:              loss = 0.3087, accuracy = 0.8683
#     Time:                      1min 59s
#
#     Training dataset:          loss = 0.2283, accuracy = 0.9118
#     Cross-validation dataset:  loss = 0.3088, accuracy = 0.8631
#     Test dataset:              loss = 0.3220, accuracy = 0.8533
#     Time:                      1min 56s

# %% [markdown]
# ### DATA:
#     Class count:    3(Ellipse, triangle, quadrilateral)
#     Colours:       Grayscale
#     Shape Type:     Perimeter only
#     Blur:           No
#     Line Thickness: Constant
#     Image Count:    10000 per class(30000 total)
#     Size:           40 x 40
#
# ### TRAINING:
#     Train on 24000 samples,
#     validate on 4800 samples
#     50 epochs
#     batch size 128
#    - kernel size (9,9)
#
#     alpha 0.001
#
# ### RESULTS:
#     Training dataset:          loss = 0.0616, accuracy = 0.9803
#     Cross-validation dataset:  loss = 0.1748, accuracy = 0.9502
#     Test dataset:              loss = 0.1541, accuracy = 0.9542
#     Time:                      2min 20s
#
#     Training dataset:          loss = 0.0856, accuracy = 0.9713
#     Cross-validation dataset:  loss = 0.1823, accuracy = 0.9429
#     Test dataset:              loss = 0.1758, accuracy = 0.9475
#     Time:                      2min 21s
#
#     Training dataset:          loss = 0.0595, accuracy = 0.9819
#     Cross-validation dataset:  loss = 0.1358, accuracy = 0.9552
#     Test dataset:              loss = 0.1390, accuracy = 0.9567
#     Time:                      2min 18s

# %% [markdown]
# ### DATA:
#     Class count:    3(Ellipse, triangle, quadrilateral)
#     Colours:       Grayscale
#    - Shape Type:     Random between Perimeter only and filled
#
#     Blur:           No
#     Line Thickness: Constant
#     Image Count:    10000 per class(30000 total)
#     Size:           40 x 40
#
# ### TRAINING:
#     Train on 24000 samples,
#     validate on 4800 samples
#     50 epochs
#     batch size 128
#    - kernel size (9,9)
#
#     alpha 0.001
#
# ### RESULTS:
#     Training dataset:          loss = 0.0616, accuracy = 0.9690
#     Cross-validation dataset:  loss = 0.1748, accuracy = 0.9202
#     Test dataset:              loss = 0.1541, accuracy = 0.9125
#     Time:                      2min 34s
#
#     Training dataset:          loss = 0.0616, accuracy = 0.9752
#     Cross-validation dataset:  loss = 0.1748, accuracy = 0.9206
#     Test dataset:              loss = 0.1541, accuracy = 0.9100
#     Time:                      2min 31s

# %% [markdown]
# Background images

# %% [markdown]
# Background images
# filled shapes
# 60000 total images(2x)
# took 5min 4s

# %% [markdown]
# edge detection 100,200
# 4 min something

# %% [markdown]
# edge detection 300 300
# 4min 39s

# %% [markdown]
# edge detection 200 300
# 4min 28s

# %% [markdown]
# normalized
# 5min 6s

# %% [markdown]
# normalized no edge detection
# 5min
